# %%
import pandas as pd

# %%
models_infos = pd.read_csv('./data/models.infos.csv')
models_infos
# Out:
#                                   model_version  \
# 0     target-only-global-2020-04-14-12-27-04-08
# 1        features-scaled-2020-04-14-14-45-36-63
# 2   2020-04-14--19-39-features-scaled-log-label
# 3   2020-04-14--22-53-features-minmax-log-label
# 4   2020-04-14--23-36-features-maxabs-log-label
# 5       2020-04-15--00-30-features-maxabs-label
# 6               2020-04-15--01-10-dew-std-label
# 7             2020-04-17--14-20-dew-min-std-log
# 8                 2020-04-17--15-19-dew-min-std
# 9          2020-04-17--17-45-dew-min-std-longer
# 10         2020-04-18--15-14-only-target-longer
# 11          2020-04-19--10-28-only-target-optim
# 12              2020-04-19--11-32-dew_min-optim
# 13          2020-04-19--12-42-only-target-optim
#
#                                              comments  epochs time_freq  \
# 0   baseline version only using the target itself ...   100.0         W
# 1   Adding 'reanalysis_avg_temp_k', 'reanalysis_ma...   100.0         W
# ...

# %%
pd.concat([models_infos.nsmallest(1, 'MAE_iq'), models_infos.nsmallest(1, 'MAE_sj')])
# Out:
#                            model_version  \
# 9   2020-04-17--17-45-dew-min-std-longer
# 12       2020-04-19--11-32-dew_min-optim
#
#                                              comments  epochs time_freq  \
# 9   only min temp and dewpoint, with no log target...   250.0         W
# 12         dew and min but longer learning - optim HP   250.0         W
#
#     num_cells  num_layers  mini_batch_size  learning_rate  \
# 9        64.0         2.0             64.0         0.0050
# 12      128.0         2.0             64.0         0.0065
#
#     early_stopping_patience  prediction_length  context_length    MAE_iq  \
# 9                      25.0              156.0            32.0  7.002216
# 12                     25.0              156.0            52.0  8.229698
#
#        MAE_sj  MAE_total
# 9   13.928264  20.930480
# 12  12.386523  20.616221

# %%
submissions_infos = pd.read_csv('./data/submissions.infos.csv')
submissions_infos
# Out:
#                                  model_version  submission_score
# 0    target-only-global-2020-04-14-12-27-04-08           33.0264
# 1       features-scaled-2020-04-14-14-45-36-63           30.9471
# 2  2020-04-14--19-39-features-scaled-log-label           35.9087
# 3                2020-04-17--15-19-dew-min-std           30.5745
# 4         2020-04-17--17-45-dew-min-std-longer           29.4423
